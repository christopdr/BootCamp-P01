# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
new_frame = pd.read_csv('Profeco_Catalog.csv')
new_frame.head(3)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0                       _id         cadenaComercial catalogo  \
# 0           0  571e4c002f232201006c6cac    HIPERMERCADO SORIANA  BASICOS
# 1           1  571e4c002f232201006c6cad                WAL-MART  BASICOS
# 2           2  571e4c002f232201006c6cae  SUPER MERCADO ARAMBURO  BASICOS
#
#                         categoria  \
# 0  TORTILLAS Y DERIVADOS DEL MAIZ
# 1  TORTILLAS Y DERIVADOS DEL MAIZ
# 2  TORTILLAS Y DERIVADOS DEL MAIZ
#
#                                            direccion               estado  \
# 0  BLVD. ADOLFO LOPEZ MATEOS 1100, ESQ. CALAFIA, ...      BAJA CALIFORNIA
# 1  CTRA. TRANSPENISULAR ENSENADA-LA PAZ 3976, ENT...      BAJA CALIFORNIA
# ...

# %%
df = pd.DataFrame(new_frame)

# %%
df.drop(columns = ['catalogo','razonSocial','rfc', 'direccion'])
# Out:
#         Unnamed: 0                       _id             cadenaComercial  \
# 0                0  571e4c002f232201006c6cac        HIPERMERCADO SORIANA
# 1                1  571e4c002f232201006c6cad                    WAL-MART
# 2                2  571e4c002f232201006c6cae      SUPER MERCADO ARAMBURO
# 3                3  571e4c002f232201006c6caf  TORTILLERIAS TRADICIONALES
# 4                4  571e4c002f232201006c6cb0  TORTILLERIAS TRADICIONALES
# 5                5  571e4c002f232201006c6cb1  TORTILLERIAS TRADICIONALES
# 6                6  571e4c002f232201006c6cb2  TORTILLERIAS TRADICIONALES
# 7                7  571e4c002f232201006c6cb3  TORTILLERIAS TRADICIONALES
# 8                8  571e4c002f232201006c6cb4  TORTILLERIAS TRADICIONALES
# 9                9  571e4c002f232201006c6cb5     MEGA COMERCIAL MEXICANA
# 10              10  571e4c002f232201006c6cb6        HIPERMERCADO SORIANA
# 11              11  571e4c002f232201006c6cb7                     SORIANA
# ...

# %%
df['fechaRegistro'].value_counts()
# Out:
# 2015-02-10 00:00:00.000    131192
# 2013-01-10 00:00:00.000     40539
# 2016-05-10 00:00:00.000     15293
# 2012-01-10 00:00:00.000      9063
# 2016-05-10 10:26:45.000         8
# 2016-05-10 10:27:21.000         8
# 2016-05-10 11:27:51.000         7
# 2016-05-10 11:16:51.000         7
# 2016-05-10 11:37:25.000         7
# 2016-05-10 10:42:24.000         7
# 2016-05-10 11:14:04.000         7
# 2016-05-10 11:30:20.000         7
# 2016-05-10 10:19:42.000         7
# 2016-05-10 10:20:40.000         7
# 2016-05-10 11:27:39.000         7
# 2016-05-10 10:18:09.000         7
# 2016-05-10 11:10:47.000         7
# 2016-05-10 10:22:05.000         7
# 2016-05-10 10:33:09.000         7
# 2016-05-10 11:20:33.000         6
# 2016-05-10 11:26:28.000         6
# 2016-05-10 10:17:17.000         6
# 2016-05-10 11:07:40.000         6
# 2016-05-10 12:21:38.000         6
# 2016-05-10 10:22:14.000         6
# 2016-05-10 10:40:16.000         6
# 2016-05-10 10:15:15.000         6
# ...

# %%
df['estado'].value_counts()
# Out:
# DISTRITO FEDERAL                   36135
# MÉXICO                             31128
# JALISCO                            15222
# GUANAJUATO                          8558
# QUINTANA ROO                        8147
# TLAXCALA                            8039
# YUCATÁN                             7573
# SONORA                              7486
# NUEVO LEÓN                          7119
# BAJA CALIFORNIA                     6771
# PUEBLA                              6304
# MICHOACÁN DE OCAMPO                 6029
# CHIHUAHUA                           5142
# COAHUILA DE ZARAGOZA                5031
# TABASCO                             4671
# TAMAULIPAS                          4553
# DURANGO                             4530
# COLIMA                              4473
# BAJA CALIFORNIA SUR                 4451
# CHIAPAS                             4022
# GUERRERO                            3985
# SINALOA                             3827
# CAMPECHE                            3694
# ...

# %%
matplotlib.pyplot.bar(x= 'estados',y= df['fecharegistro'].value_count('estados')., width=0.8, bottom=None, *, align='center')
# Out:
#   File "<ipython-input-59-e29650958766>", line 1
#     matplotlib.pyplot.bar(x= 'estados',y= df['fecharegistro'].value_count('estados')., width=0.8, bottom=None, *, align='center')
#                                                                                      ^
# SyntaxError: invalid syntax

# %%
df[new_frame].to_numeric(new_frame['precio'], downcast = 'float')
df[new_frame].to_numeric(new_frame['latitud'], downcast = 'float')
df[new_frame].to_numeric(new_frame['longitud'], downcast = 'float')
precio = int("precio")
arr = precio.sum()
ax.stackplot(x= "estado", y1= arr("precio"), labels=labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ab1d3f6353b9> in <module>()
# ----> 1 df.plot.hist(x= 'estado', y= 'precio')
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwds)
#    3264             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    3265         """
# -> 3266         return self(kind='hist', by=by, bins=bins, **kwds)
#    3267
#    3268     @Appender(_kde_docstring % {
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...
