# %%
import requests
import json
import pandas as pd
from datetime import datetime

# %%
url = "https://api.datos.gob.mx/v2/profeco.precios"
response_json= requests.get(url).json()
print("Server Response: " + str(response_json))
# Out:
# Server Response: <Response [200]>

# %%
total_size = response_json["pagination"]["total"]
print('Number of elements in Profeco Database: ' + str(total_size))
# Out:
# Number of elements in Profeco Database: 219584

# %%
page_number = round(total_size/1000)
page_size = 1000
url_param1 = '?pageSize='
url_param2 = '&page='
#https://api.datos.gob.mx/v2/profeco.precios?pageSize=1000&page=1
search_url = ''
json_list = []
for page in range(1,page_number + 1): #
    if page == page_number:
        search_url = url + url_param1 + str(total_size%1000) + url_param2 + str(page)
    else:
        search_url = url + url_param1 + str(page_size) + url_param2 + str(page)

    json_data = requests.get(search_url).json()
    json_list = json_list + json_data['results']
    #print('Page: ' + str(page))
    #print('No. Elements: ' + str(len(json_data['results'])))
    #print('Working...')

print(len(json_list))
# Out:
# 219584

# %%
data_frame = pd.DataFrame(json_list)
data_frame = data_frame.drop(data_frame[data_frame['fechaRegistro'] == 'fechaRegistro'].index)
#data_frame['fechaRegistro'] = data_frame['fechaRegistro'].apply(lambda elem : datetime.strptime(str(elem).split(' ')[0],"%Y-%m-%d")) 
data_frame['fechaRegistro'] = pd.to_datetime(data_frame['fechaRegistro'], format='%Y-%m-%d')

data_frame.to_csv('Profeco_Catalog.csv', encoding='utf-8')
data_frame.dtypes
# Out:
# _id                        object
# cadenaComercial            object
# catalogo                   object
# categoria                  object
# direccion                  object
# estado                     object
# fechaRegistro      datetime64[ns]
# giro                       object
# latitud                    object
# longitud                   object
# marca                      object
# municipio                  object
# nombreComercial            object
# precio                     object
# presentacion               object
# producto                   object
# razonSocial                object
# rfc                        object
# dtype: object

# %%
data_frame.head(3)
# Out:
#                         _id         cadenaComercial catalogo  \
# 0  571e4c002f232201006c6cac    HIPERMERCADO SORIANA  BASICOS
# 1  571e4c002f232201006c6cad                WAL-MART  BASICOS
# 2  571e4c002f232201006c6cae  SUPER MERCADO ARAMBURO  BASICOS
#
#                         categoria  \
# 0  TORTILLAS Y DERIVADOS DEL MAIZ
# 1  TORTILLAS Y DERIVADOS DEL MAIZ
# 2  TORTILLAS Y DERIVADOS DEL MAIZ
#
#                                            direccion               estado  \
# 0  BLVD. ADOLFO LOPEZ MATEOS 1100, ESQ. CALAFIA, ...      BAJA CALIFORNIA
# 1  CTRA. TRANSPENISULAR ENSENADA-LA PAZ 3976, ENT...      BAJA CALIFORNIA
# 2  FORJADORES DE SUDCALIFORNIA 2910, ENTRE ALAMO ...  BAJA CALIFORNIA SUR
#
#   fechaRegistro                    giro    latitud     longitud marca  \
# 0    2015-02-10  TIENDA DE AUTOSERVICIO  32.641719  -115.469582   S/M
# 1    2015-02-10  TIENDA DE AUTOSERVICIO  31.859079  -116.606337   S/M
# 2    2015-02-10  TIENDA DE AUTOSERVICIO  24.135925  -110.311974   S/M
#
#   municipio                             nombreComercial precio  presentacion  \
# 0  MEXICALI              SORIANA HIPER SUCURSAL CALAFIA  11.90  1 KG. GRANEL
# 1  ENSENADA                   WALMART SUCURSAL ENSENADA   9.50  1 KG. GRANEL
# 2    LA PAZ  SUPER MERCADO ARAMBURO SUCURSAL FORJADORES   9.90  1 KG. GRANEL
#
#            producto razonSocial rfc
# 0  TORTILLA DE MAIZ
# 1  TORTILLA DE MAIZ
# 2  TORTILLA DE MAIZ

# %%
new_frame = pd.read_csv('Profeco_Catalog.csv')
new_frame.head(3)
# Out:
#    Unnamed: 0                       _id         cadenaComercial catalogo  \
# 0           0  571e4c002f232201006c6cac    HIPERMERCADO SORIANA  BASICOS
# 1           1  571e4c002f232201006c6cad                WAL-MART  BASICOS
# 2           2  571e4c002f232201006c6cae  SUPER MERCADO ARAMBURO  BASICOS
#
#                         categoria  \
# 0  TORTILLAS Y DERIVADOS DEL MAIZ
# 1  TORTILLAS Y DERIVADOS DEL MAIZ
# 2  TORTILLAS Y DERIVADOS DEL MAIZ
#
#                                            direccion               estado  \
# 0  BLVD. ADOLFO LOPEZ MATEOS 1100, ESQ. CALAFIA, ...      BAJA CALIFORNIA
# 1  CTRA. TRANSPENISULAR ENSENADA-LA PAZ 3976, ENT...      BAJA CALIFORNIA
# 2  FORJADORES DE SUDCALIFORNIA 2910, ENTRE ALAMO ...  BAJA CALIFORNIA SUR
#
#   fechaRegistro                    giro    latitud    longitud marca  \
# 0    2015-02-10  TIENDA DE AUTOSERVICIO  32.641719 -115.469582   S/M
# 1    2015-02-10  TIENDA DE AUTOSERVICIO  31.859079 -116.606337   S/M
# 2    2015-02-10  TIENDA DE AUTOSERVICIO  24.135925 -110.311974   S/M
#
#   municipio                             nombreComercial  precio  presentacion  \
# 0  MEXICALI              SORIANA HIPER SUCURSAL CALAFIA    11.9  1 KG. GRANEL
# 1  ENSENADA                   WALMART SUCURSAL ENSENADA     9.5  1 KG. GRANEL
# 2    LA PAZ  SUPER MERCADO ARAMBURO SUCURSAL FORJADORES     9.9  1 KG. GRANEL
#
#            producto  razonSocial  rfc
# 0  TORTILLA DE MAIZ          NaN  NaN
# 1  TORTILLA DE MAIZ          NaN  NaN
# 2  TORTILLA DE MAIZ          NaN  NaN

# %%
new_frame[new_frame['_id'] == '5769ca75d4c5840100096dc1']
# Out:
#         Unnamed: 0                       _id cadenaComercial catalogo  \
# 209935      209937  5769ca75d4c5840100096dc1  BODEGA AURRERA  BASICOS
#
#                              categoria  \
# 209935  TORTILLAS Y DERIVADOS DEL MAIZ
#
#                                        direccion  estado fechaRegistro  \
# 209935  P DE LA CONSTITUCION  LT. 1 MZ. C - 34-B  MÉXICO    2012-01-10
#
#                           giro    latitud   longitud marca  \
# 209935  TIENDA DE AUTOSERVICIO  19.654503 -99.206484   S/M
#
#                                        municipio  \
# 209935  CUAUTITLAN
#
#                              nombreComercial  precio  presentacion  \
# 209935  AURRERA BODEGA SUCURSAL CUAUTITLAN 1     7.9  1 KG. GRANEL
#
#                 producto  razonSocial  rfc
# 209935  TORTILLA DE MAIZ          NaN  NaN
